# %% [markdown]
# ## comments on homework
#
# keep examining your data and your visualizations
#
#
# example:
# homework of week 1 --- plotting the five largest earthquakes on your birthday
#
# why it appears that there are only 4 dots on this plot?
#
# why is it quite common that there are overlapping dots?
#
# ![](./office_hour_data/homework_img.png)
#
# the Jupyter Notebook environment provides an excellent platform for you to show your data analyses procedure and work towards your interpretations/conclusions.
#
# How can you show that there are two earthquakes that are overlapping using the Pandas table?
#
# How can you change the settings of the plot function such that the somewhat overlapping symbols can be better distinguished?

# %% [markdown]
# # Week 1 office hour short topic: Pandas
#
# - The goal of office hours this semster for EPS 88 is to give short optional topics on uisng Python tools

# %% [markdown]
# ## Introduction to Pandas package
#
# This short Pandas package introduction is inspired by the lecture notes given by UC Berkeley Data 100 course: https://ds100.org/sp23/.
#
# You can find the slides and demo code related to their Pandas introduction topics here: https://ds100.org/sp23/lecture/lec02/.
#
# We will briefly go through Pandas practices during office hours this week with example Earth science data.

# %%
# import the Pandas package, you have seen this in the first week in-class and homework assignments. 

import pandas as pd

# %% [markdown]
# ### File navigation
#
# While we practiced obtaiing earthquake data from the USGS earthquake API. We can also use pandas to process local data files.

# %%
# let's find the data file

# data = pd.read_csv('../../..')
data = pd.read_csv('./office_hour_data/query.csv')

# %% [markdown]
# ### Displaying dataframes

# %%
# display a dataframe
data
# Out:
#                          time   latitude   longitude    depth  mag magType  \
# 0    1983-01-09T21:03:54.230Z  55.179000  163.244000   33.000  6.1      ms
# 1    1983-01-09T10:42:47.760Z  55.163000  163.125000   33.000  5.3      ms
# 2    1983-01-09T13:24:03.710Z -56.902000  147.557000   10.000  5.3      ms
# 3    1983-01-09T18:36:46.860Z  35.463000  140.212000   80.900  5.0      mb
# 4    1983-01-09T05:09:16.830Z  55.138000  163.080000   33.000  4.9      mb
# ..                        ...        ...         ...      ...  ...     ...
# 278  1983-01-09T11:57:33.630Z  37.637000 -118.925500    4.230  NaN     NaN
# 279  1983-01-09T11:57:34.830Z  37.635167 -118.923333    3.877  NaN     NaN
# 280  1983-01-09T12:24:03.430Z  63.264000 -149.790000  102.900  NaN     NaN
# 281  1983-01-09T18:43:43.110Z   9.891000  -69.790000   10.000  NaN     NaN
# 282  1983-01-09T18:54:27.270Z  40.707000   23.175000   10.000  NaN     NaN
#
#       nst    gap     dmin   rms  ...                   updated  \
# ...

# %%
# display certain columns
data[['latitude', 'depth', ]]
# Out:
#       latitude    depth
# 0    55.179000   33.000
# 1    55.163000   33.000
# 2   -56.902000   10.000
# 3    35.463000   80.900
# 4    55.138000   33.000
# ..         ...      ...
# 278  37.637000    4.230
# 279  37.635167    3.877
# 280  63.264000  102.900
# 281   9.891000   10.000
# 282  40.707000   10.000
#
# [283 rows x 2 columns]

# %%
# display certain rows
data.loc[0] # say the first row
# Out:
# time                                  1983-01-09T21:03:54.230Z
# latitude                                                55.179
# longitude                                              163.244
# depth                                                     33.0
# mag                                                        6.1
# magType                                                     ms
# nst                                                        NaN
# gap                                                        NaN
# dmin                                                       NaN
# rms                                                        1.0
# net                                                         us
# id                                                  usp0001s40
# updated                               2022-04-28T00:15:30.852Z
# place              126 km SSE of Ust’-Kamchatsk Staryy, Russia
# type                                                earthquake
# ...

# %%
# display certain rows
data.loc[8:] # say the first ten rows
# Out:
#                          time   latitude   longitude    depth   mag magType  \
# 8    1983-01-09T08:08:34.580Z  -8.752000  112.594000   88.900  4.50      mb
# 9    1983-01-09T14:58:57.010Z  39.115000 -119.555000    5.000  3.80      ml
# 10   1983-01-09T00:50:15.190Z  19.366500 -155.257167   32.642  3.47      ml
# 11   1983-01-09T11:57:54.670Z  37.873667 -119.842167    3.791  3.40      ml
# 12   1983-01-09T11:04:34.670Z  37.622000 -118.872667    5.686  3.23      md
# ..                        ...        ...         ...      ...   ...     ...
# 278  1983-01-09T11:57:33.630Z  37.637000 -118.925500    4.230   NaN     NaN
# 279  1983-01-09T11:57:34.830Z  37.635167 -118.923333    3.877   NaN     NaN
# 280  1983-01-09T12:24:03.430Z  63.264000 -149.790000  102.900   NaN     NaN
# 281  1983-01-09T18:43:43.110Z   9.891000  -69.790000   10.000   NaN     NaN
# 282  1983-01-09T18:54:27.270Z  40.707000   23.175000   10.000   NaN     NaN
#
# ...

# %% [markdown]
# ### Pandas data structure
#
# - Series
# - index
# - dataframe

# %%
type(data['latitude'])
# Out:
# pandas.core.series.Series

# %%
type(data.index)
# Out:
# pandas.core.indexes.range.RangeIndex

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
type(data.loc[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Full documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %% [markdown]
# ### make a Pandas DataFrame from scratch

# %%
pd.DataFrame??
# Out:
# Init signature:
# pd.DataFrame(
#     data=None,
#     index: 'Axes | None' = None,
#     columns: 'Axes | None' = None,
#     dtype: 'Dtype | None' = None,
#     copy: 'bool | None' = None,
# )
# Source:
# class DataFrame(NDFrame, OpsMixin):
#     """
#     Two-dimensional, size-mutable, potentially heterogeneous tabular data.
#
#     Data structure also contains labeled axes (rows and columns).
#     Arithmetic operations align on both row and column labels. Can be
#     thought of as a dict-like container for Series objects. The primary
#     pandas data structure.
#
#     Parameters
#     ----------
#     data : ndarray (structured or homogeneous), Iterable, dict, or DataFrame
#         Dict can contain Series, arrays, constants, dataclass or list-like objects. If
#         data is a dict, column order follows insertion-order. If a dict contains Series
#         which have an index defined, it is aligned by its index.
#
#         .. versionchanged:: 0.25.0
# ...

# %%
pd.DataFrame([1, 2, 3],
             columns=["Numbers"])
# Out:
#    Numbers
# 0        1
# 1        2
# 2        3

# %%
pd.DataFrame([[1, "one"], [2, "two"]],
            columns = ["Number", "Description"])
# Out:
#    Number Description
# 0       1         one
# 1       2         two

# %%
pd.DataFrame({"Fruit":["Strawberry", "Orange"], 
              "Price": [5.49, 3.99]})
# Out:
#         Fruit  Price
# 0  Strawberry   5.49
# 1      Orange   3.99

# %%
pd.DataFrame([{"Fruit":"Strawberry", "Price":5.49},
             {"Fruit":"Orange", "Price":3.99}])
# Out:
#         Fruit  Price
# 0  Strawberry   5.49
# 1      Orange   3.99
